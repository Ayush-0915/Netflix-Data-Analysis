# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit

# %%
df = pd.read_csv('mymoviedb.csv', lineterminator ='\n')

# %%
df.head(20)
# Out:
#    Release_Date                                    Title  \
# 0    2021-12-15                  Spider-Man: No Way Home
# 1    2022-03-01                               The Batman
# 2    2022-02-25                                  No Exit
# 3    2021-11-24                                  Encanto
# 4    2021-12-22                           The King's Man
# 5    2022-01-07                             The Commando
# 6    2022-01-12                                   Scream
# 7    2022-02-10                                     Kimi
# 8    2022-02-17                     Fistful of Vengeance
# 9    2021-11-03                                 Eternals
# 10   2022-02-18                                  Pursuit
# 11   2021-08-06  My Hero Academia: World Heroes' Mission
# 12   2022-02-25                                 Restless
# 13   2021-12-02                          Nightmare Alley
# 14   2022-01-28      The Ice Age Adventures of Buck Wild
# ...

# %%
df.info() #to get the info about the data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df['Genre'].head()     # To get info of genre
# Out:
# 0    Action, Adventure, Science Fiction
# 1              Crime, Mystery, Thriller
# 2                              Thriller
# 3    Animation, Comedy, Family, Fantasy
# 4      Action, Adventure, Thriller, War
# Name: Genre, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()  #Statistical Info
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9827.000000   9827.000000
# mean     40.326088   1392.805536      6.439534
# std     108.873998   2611.206907      1.129759
# min      13.354000      0.000000      0.000000
# 25%      16.128500    146.000000      5.900000
# 50%      21.199000    444.000000      6.500000
# 75%      35.191500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %% [markdown]
# Dropping the Columns

# %%
#Remove the column from dataset
cols = ['Overview', 'Original_Language', 'Poster_Url']

# %%
df.drop(cols, axis = 1, inplace = True)
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Popularity', 'Vote_Count', 'Vote_Average',
#        'Genre'],
#       dtype='object')

# %%
df.head()
# Out:
#   Release_Date                    Title  Popularity  Vote_Count  Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940           8.3
# 1   2022-03-01               The Batman    3827.658        1151           8.1
# 2   2022-02-25                  No Exit    2618.087         122           6.3
# 3   2021-11-24                  Encanto    2402.201        5076           7.7
# 4   2021-12-22           The King's Man    1895.511        1793           7.0
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
#change the form of data in dictionary form
data_dict = df.to_dict()

# %%
print(data_dict)
# Out:
# {'Release_Date': {0: Timestamp('2021-12-15 00:00:00'), 1: Timestamp('2022-03-01 00:00:00'), 2: Timestamp('2022-02-25 00:00:00'), 3: Timestamp('2021-11-24 00:00:00'), 4: Timestamp('2021-12-22 00:00:00'), 5: Timestamp('2022-01-07 00:00:00'), 6: Timestamp('2022-01-12 00:00:00'), 7: Timestamp('2022-02-10 00:00:00'), 8: Timestamp('2022-02-17 00:00:00'), 9: Timestamp('2021-11-03 00:00:00'), 10: Timestamp('2022-02-18 00:00:00'), 11: Timestamp('2021-08-06 00:00:00'), 12: Timestamp('2022-02-25 00:00:00'), 13: Timestamp('2021-12-02 00:00:00'), 14: Timestamp('2022-01-28 00:00:00'), 15: Timestamp('2022-02-25 00:00:00'), 16: Timestamp('2022-02-18 00:00:00'), 17: Timestamp('2022-01-28 00:00:00'), 18: Timestamp('2022-02-04 00:00:00'), 19: Timestamp('2021-11-04 00:00:00'), 20: Timestamp('2021-12-01 00:00:00'), 21: Timestamp('2022-01-03 00:00:00'), 22: Timestamp('2021-09-30 00:00:00'), 23: Timestamp('2021-12-16 00:00:00'), 24: Timestamp('2021-11-24 00:00:00'), 25: Timestamp('2021-10-19 00:00:00'), 26
# ...

# %%
#give the last 5 rows of dataset
df.tail()
# Out:
#      Release_Date                                 Title  Popularity  \
# 9822   1973-10-15                              Badlands      13.357
# 9823   2020-10-01                      Violent Delights      13.356
# 9824   2016-05-06                          The Offering      13.355
# 9825   2021-03-31  The United States vs. Billie Holiday      13.354
# 9826   1984-09-23                               Threads      13.354
#
#       Vote_Count  Vote_Average                        Genre
# 9822         896           7.6                 Drama, Crime
# 9823           8           3.5                       Horror
# 9824          94           5.0    Mystery, Thriller, Horror
# 9825         152           6.7        Music, Drama, History
# 9826         186           7.8  War, Drama, Science Fiction

# %%
#save the file in json format
df.to_json('Output.json',index=False)

# %%
#used for acess the specific coloumn in dataset
print(df.iloc[3,2])
# Out:
# 2402.201

# %%
 # exploring column
 df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# 6.4     435
# 6.3     429
# 6.5     427
# 6.8     423
# 6.7     420
#        ...
# 2.2       1
# 9.2       1
# 1.5       1
# 3.1       1
# 10.0      1
# Name: count, Length: 74, dtype: int64

# %%
#sort the data according to given condition in boolean form
print(df['Popularity']>300)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9822    False
# 9823    False
# 9824    False
# 9825    False
# 9826    False
# Name: Popularity, Length: 9827, dtype: bool

# %%
#sort the data according to given condition in proper form
print(df[df['Popularity']>300])
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0    2021-12-15  Spider-Man: No Way Home    5083.954        8940
# 1    2022-03-01               The Batman    3827.658        1151
# 2    2022-02-25                  No Exit    2618.087         122
# 3    2021-11-24                  Encanto    2402.201        5076
# 4    2021-12-22           The King's Man    1895.511        1793
# ..          ...                      ...         ...         ...
# 87   2021-02-11               Dark Spell     308.037          80
# 88   2021-07-28            Jungle Cruise     307.936        4034
# 89   2021-03-24        Godzilla vs. Kong     307.521        7681
# 90   2012-06-23   The Amazing Spider-Man     306.376       14564
# 91   2022-02-17               Heart Shot     302.272          16
#
#     Vote_Average                               Genre
# 0            8.3  Action, Adventure, Science Fiction
# 1            8.1            Crime, Mystery, Thriller
# ...

# %%
#find if there is any null value in dataset
df.isnull().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# dtype: int64

# %%
#if there is any null value fill a temporary value in place of it
df.fillna(0)
# Out:
#      Release_Date                                 Title  Popularity  \
# 0      2021-12-15               Spider-Man: No Way Home    5083.954
# 1      2022-03-01                            The Batman    3827.658
# 2      2022-02-25                               No Exit    2618.087
# 3      2021-11-24                               Encanto    2402.201
# 4      2021-12-22                        The King's Man    1895.511
# ...           ...                                   ...         ...
# 9822   1973-10-15                              Badlands      13.357
# 9823   2020-10-01                      Violent Delights      13.356
# 9824   2016-05-06                          The Offering      13.355
# 9825   2021-03-31  The United States vs. Billie Holiday      13.354
# 9826   1984-09-23                               Threads      13.354
#
#       Vote_Count  Vote_Average                               Genre
# 0           8940           8.3  Action, Adventure, Science Fiction
# ...

# %%
#if there is any null value drop it
df.dropna()
# Out:
#      Release_Date                                 Title  Popularity  \
# 0      2021-12-15               Spider-Man: No Way Home    5083.954
# 1      2022-03-01                            The Batman    3827.658
# 2      2022-02-25                               No Exit    2618.087
# 3      2021-11-24                               Encanto    2402.201
# 4      2021-12-22                        The King's Man    1895.511
# ...           ...                                   ...         ...
# 9822   1973-10-15                              Badlands      13.357
# 9823   2020-10-01                      Violent Delights      13.356
# 9824   2016-05-06                          The Offering      13.355
# 9825   2021-03-31  The United States vs. Billie Holiday      13.354
# 9826   1984-09-23                               Threads      13.354
#
#       Vote_Count  Vote_Average                               Genre
# 0           8940           8.3  Action, Adventure, Science Fiction
# ...

# %%
#save the file in csv and excel format
df.to_csv('output.csv',index=False)
df.to_excel('output.xlsx',index=False)

# %%
#read the csv file
data = pd.read_csv('output.csv')

# %%
data.head()
# Out:
#   Release_Date                    Title  Popularity  Vote_Count  Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940           8.3
# 1   2022-03-01               The Batman    3827.658        1151           8.1
# 2   2022-02-25                  No Exit    2618.087         122           6.3
# 3   2021-11-24                  Encanto    2402.201        5076           7.7
# 4   2021-12-22           The King's Man    1895.511        1793           7.0
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
data.tail()
# Out:
#      Release_Date                                 Title  Popularity  \
# 9822   1973-10-15                              Badlands      13.357
# 9823   2020-10-01                      Violent Delights      13.356
# 9824   2016-05-06                          The Offering      13.355
# 9825   2021-03-31  The United States vs. Billie Holiday      13.354
# 9826   1984-09-23                               Threads      13.354
#
#       Vote_Count  Vote_Average                        Genre
# 9822         896           7.6                 Drama, Crime
# 9823           8           3.5                       Horror
# 9824          94           5.0    Mystery, Thriller, Horror
# 9825         152           6.7        Music, Drama, History
# 9826         186           7.8  War, Drama, Science Fiction

# %%
#find if there is any duplicated value in dataset
print(data.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9822    False
# 9823    False
# 9824    False
# 9825    False
# 9826    False
# Length: 9827, dtype: bool

# %%
#drop the duplicated value from the dataset
data.drop_duplicates()
# Out:
#      Release_Date                                 Title  Popularity  \
# 0      2021-12-15               Spider-Man: No Way Home    5083.954
# 1      2022-03-01                            The Batman    3827.658
# 2      2022-02-25                               No Exit    2618.087
# 3      2021-11-24                               Encanto    2402.201
# 4      2021-12-22                        The King's Man    1895.511
# ...           ...                                   ...         ...
# 9822   1973-10-15                              Badlands      13.357
# 9823   2020-10-01                      Violent Delights      13.356
# 9824   2016-05-06                          The Offering      13.355
# 9825   2021-03-31  The United States vs. Billie Holiday      13.354
# 9826   1984-09-23                               Threads      13.354
#
#       Vote_Count  Vote_Average                               Genre
# 0           8940           8.3  Action, Adventure, Science Fiction
# ...

# %%
#give the specific value of column
print(df.iat[3,2])
# Out:
# 2402.201

# %%
df.to_excel('Final_output.xlsx',index=False)
